# %%
from ztfquery import query
from astropy.time import Time
import numpy as np
# %matplotlib inline

# %%
zquery = query.ZTFQuery()
jdstart = Time("2019-04-25").jd
jdend = Time("2019-04-26").jd
zquery.load_metadata(sql_query=f"seeing<2 and obsjd BETWEEN {jdstart} AND {jdend}")

# %%
query_table = zquery.metatable
query_table
# Out:
#                ra        dec  infobits  field  ccdid  qid  rcid  fid  \
# 0      171.685376 -18.434227         0    318      6    3    22    2
# 1      167.738224 -20.319191         0    318      4    3    14    2
# 2      168.713493 -16.503091         0    318     12    4    47    2
# 3      173.669286 -20.327246         0    318      1    3     2    2
# 4      169.739161 -17.561981         0    318      7    2    25    2
# ...           ...        ...       ...    ...    ...  ...   ...  ...
# 31389  228.828344   5.943337         0    479      9    2    33    1
# 31390  227.818947   3.165006         0    479      6    4    23    1
# 31391  226.949771   1.252879         0    479      2    3     6    1
# 31392  224.096413   6.996538         0    479     16    4    63    1
# 31393  229.697392   5.939373         0    479      9    1    32    1
#
#       filtercode           pid  ...         ra1       dec1         ra2  \
# 0             zr  844140352215  ...  172.137965 -17.998894  171.229400
# 1             zr  844140351415  ...  168.206213 -19.893490  167.287678
# 2             zr  844140354715  ...  169.167256 -16.073520  168.267956
# 3             zr  844140350215  ...  174.122924 -19.888298  173.204221
# 4             zr  844140352515  ...  170.193481 -17.130391  169.289380
# ...          ...           ...  ...         ...        ...         ...
# 31389         zg  844506453315  ...  229.265156   6.374643  228.395666
# 31390         zg  844506452315  ...  228.253201   3.597154  227.387075
# 31391         zg  844506450615  ...  227.383007   1.685586  226.518297
# 31392         zg  844506456315  ...  224.530574   7.431301  223.658923
# 31393         zg  844506453215  ...  230.134508   6.369744  229.265147
#
#             dec2         ra3       dec3         ra4       dec4  \
# 0     -18.001773  171.230781 -18.868273  172.143755 -18.865504
# 1     -19.877327  167.267831 -20.743488  168.191337 -20.759970
# 2     -16.065174  168.257613 -16.931597  169.160644 -16.939816
# 3     -19.898458  173.213348 -20.764885  174.136976 -20.754751
# 4     -17.126163  169.282712 -17.992554  170.191299 -17.997001
# ...          ...         ...        ...         ...        ...
# 31389   6.377790  228.392341   5.511607  229.260638   5.508305
# 31390   3.599262  227.385021   2.732701  228.250162   2.730827
# 31391   1.686741  226.516964   0.820286  227.381145   0.818911
# 31392   7.427926  223.662918   6.561515  224.532801   6.564984
# 31393   6.374623  229.260656   5.508313  230.129033   5.503738
#
#                 ipac_pub_date  ipac_gid
# 0      2019-12-11 00:00:00+00         1
# 1      2019-12-11 00:00:00+00         1
# 2      2019-12-11 00:00:00+00         1
# 3      2019-12-11 00:00:00+00         1
# 4      2019-12-11 00:00:00+00         1
# ...                       ...       ...
# 31389  2020-12-09 00:00:00+00         2
# 31390  2020-12-09 00:00:00+00         2
# 31391  2020-12-09 00:00:00+00         2
# 31392  2020-12-09 00:00:00+00         2
# 31393  2020-12-09 00:00:00+00         2
#
# [31394 rows x 42 columns]

# %%
zquery.show_gri_fields(title="Observations taken on 2019-04-25", grid="main")
# Out:
# C:\Users\barve\Anaconda3\envs\ztfsummer\lib\site-packages\ztfquery\utils\tools.py:76: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.asarray([v[0]*np.cos(theta*_DEG2RA) - v[2]*np.sin(theta*_DEG2RA),
# WARNING: AstropyDeprecationWarning: Transforming a frame instance to a frame class (as opposed to another frame instance) will not be supported in the future.  Either explicitly instantiate the target frame, or first convert the source frame instance to a `astropy.coordinates.SkyCoord` and use its `transform_to()` method. [astropy.coordinates.baseframe]
# C:\Users\barve\Anaconda3\envs\ztfsummer\lib\site-packages\ztfquery\utils\tools.py:76: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.asarray([v[0]*np.cos(theta*_DEG2RA) - v[2]*np.sin(theta*_DEG2RA),
# WARNING: AstropyDeprecationWarning: Transforming a frame instance to a frame class (as opposed to another frame instance) will not be supported in the future.  Either explicitly instantiate the target frame, or first convert the source frame instance to a `astropy.coordinates.SkyCoord` and use its `transform_to()` method. [astropy.coordinates.baseframe]
# C:\Users\barve\Anaconda3\envs\ztfsummer\lib\site-packages\ztfquery\utils\tools.py:76: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.asarray([v[0]*np.cos(theta*_DEG2RA) - v[2]*np.sin(theta*_DEG2RA),
# <HammerAxes:>

# %%
query_table.columns
# Out:
# Index(['ra', 'dec', 'infobits', 'field', 'ccdid', 'qid', 'rcid', 'fid',
#        'filtercode', 'pid', 'nid', 'expid', 'itid', 'imgtype', 'imgtypecode',
#        'obsdate', 'obsjd', 'exptime', 'filefracday', 'seeing', 'airmass',
#        'moonillf', 'moonesb', 'maglimit', 'crpix1', 'crpix2', 'crval1',
#        'crval2', 'cd11', 'cd12', 'cd21', 'cd22', 'ra1', 'dec1', 'ra2', 'dec2',
#        'ra3', 'dec3', 'ra4', 'dec4', 'ipac_pub_date', 'ipac_gid'],
#       dtype='object')

# %%
zquery = query.ZTFQuery()
jdstart = Time("2021-04-25").jd
jdend = Time("2021-04-26").jd
zquery.load_metadata(sql_query=f"seeing<2 and obsjd BETWEEN {jdstart} AND {jdend}")

# %%
query_table = zquery.metatable
query_table
# Out:
#               ra        dec  infobits  field  ccdid  qid  rcid  fid  \
# 0     111.656413  39.988977         0    707      8    1    28    1
# 1     115.370119  39.166580         0    707      6    3    22    1
# 2     112.983229  39.152678         0    707      7    3    26    1
# 3     115.359479  37.253312         0    707      2    3     6    1
# 4     115.364433  38.119752         0    707      2    2     5    1
# ...          ...        ...       ...    ...    ...  ...   ...  ...
# 5537  287.007577  55.427203         0    799     12    4    47    1
# 5538  293.421193  53.540539         0    799      6    4    23    1
# 5539  283.029156  37.194489         0    727      4    3    14    1
# 5540  282.984290  38.060054         0    727      4    2    13    1
# 5541  284.113406  37.224852         0    727      4    4    15    1
#
#      filtercode            pid  ...         ra1       dec1         ra2  \
# 0            zg  1575181462815  ...  112.201204  40.437124  111.067201
# 1            zg  1575181462215  ...  115.933565  39.596378  114.811997
# 2            zg  1575181462615  ...  113.530540  39.594762  112.409467
# 3            zg  1575181460615  ...  115.907907  37.683295  114.816024
# 4            zg  1575181460515  ...  115.919499  38.549570  114.814722
# ...         ...            ...  ...         ...        ...         ...
# 5537         zg  1575483634715  ...  287.732344  55.882313  286.195161
# 5538         zg  1575483632315  ...  294.181796  53.955371  292.713450
# 5539         zg  1575484581415  ...  283.552044  37.643849  282.462081
# 5540         zg  1575484581315  ...  283.513020  38.509518  282.410289
# 5541         zg  1575484581515  ...  284.642965  37.669314  283.552067
#
#            dec2         ra3       dec3         ra4       dec4  \
# 0     40.403245  111.118378  39.538072  112.238447  39.571558
# 1     39.600489  114.813909  38.734331  115.921422  38.730107
# 2     39.574004  112.443134  38.708349  113.550172  38.728566
# 3     37.687217  114.817670  36.821006  115.896677  36.816979
# 4     38.553355  114.816036  37.687209  115.907916  37.683285
# ...         ...         ...        ...         ...        ...
# 5537  55.832305  286.299163  54.967994  287.802839  55.017035
# 5538  53.987161  292.675447  53.121002  294.113661  53.090117
# 5539  37.608166  282.512709  36.743076  283.589989  36.778085
# 5540  38.473137  282.462080  37.608159  283.552067  37.643861
# 5541  37.643864  283.590004  36.778077  284.668101  36.803354
#
#                ipac_pub_date  ipac_gid
# 0     2021-06-30 00:00:00+00         1
# 1     2021-06-30 00:00:00+00         1
# 2     2021-06-30 00:00:00+00         1
# 3     2021-06-30 00:00:00+00         1
# 4     2021-06-30 00:00:00+00         1
# ...                      ...       ...
# 5537  2021-06-30 00:00:00+00         1
# 5538  2021-06-30 00:00:00+00         1
# 5539  2021-06-30 00:00:00+00         1
# 5540  2021-06-30 00:00:00+00         1
# 5541  2021-06-30 00:00:00+00         1
#
# [5542 rows x 42 columns]

# %%
zquery.show_gri_fields(title="Observations taken on 2021-04-25", grid="main")
# Out:
# C:\Users\barve\Anaconda3\envs\ztfsummer\lib\site-packages\ztfquery\utils\tools.py:76: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.asarray([v[0]*np.cos(theta*_DEG2RA) - v[2]*np.sin(theta*_DEG2RA),
# WARNING: AstropyDeprecationWarning: Transforming a frame instance to a frame class (as opposed to another frame instance) will not be supported in the future.  Either explicitly instantiate the target frame, or first convert the source frame instance to a `astropy.coordinates.SkyCoord` and use its `transform_to()` method. [astropy.coordinates.baseframe]
# C:\Users\barve\Anaconda3\envs\ztfsummer\lib\site-packages\ztfquery\utils\tools.py:76: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.asarray([v[0]*np.cos(theta*_DEG2RA) - v[2]*np.sin(theta*_DEG2RA),
# WARNING: AstropyDeprecationWarning: Transforming a frame instance to a frame class (as opposed to another frame instance) will not be supported in the future.  Either explicitly instantiate the target frame, or first convert the source frame instance to a `astropy.coordinates.SkyCoord` and use its `transform_to()` method. [astropy.coordinates.baseframe]
# C:\Users\barve\Anaconda3\envs\ztfsummer\lib\site-packages\ztfquery\utils\tools.py:76: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.asarray([v[0]*np.cos(theta*_DEG2RA) - v[2]*np.sin(theta*_DEG2RA),
# <HammerAxes:>

# %%
query_table.columns
# Out:
# Index(['ra', 'dec', 'infobits', 'field', 'ccdid', 'qid', 'rcid', 'fid',
#        'filtercode', 'pid', 'nid', 'expid', 'itid', 'imgtype', 'imgtypecode',
#        'obsdate', 'obsjd', 'exptime', 'filefracday', 'seeing', 'airmass',
#        'moonillf', 'moonesb', 'maglimit', 'crpix1', 'crpix2', 'crval1',
#        'crval2', 'cd11', 'cd12', 'cd21', 'cd22', 'ra1', 'dec1', 'ra2', 'dec2',
#        'ra3', 'dec3', 'ra4', 'dec4', 'ipac_pub_date', 'ipac_gid'],
#       dtype='object')

# %%
zquery.load_metadata(sql_query=f"maglimit>21 AND filtercode='zg' AND obsjd BETWEEN {jdstart} AND {jdend}")
# Out:
# C:\Users\barve\Anaconda3\envs\ztfsummer\lib\site-packages\ztfquery\metasearch.py:145: UserWarning: The query ran successfully, but no data returned. (bad query [check self.query_url]? wrong password [ztfquery.io._load_id_('irsa')] ?)
#   warnings.warn("The query ran successfully, but no data returned. (bad query [check self.query_url]? wrong password [ztfquery.io._load_id_('irsa')] ?)")

# %%
zquery.show_gri_fields(title='deep g-band observations')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21232/387701844.py in <module>
# ----> 1 zquery.show_gri_fields(title='deep g-band observations')
#
# ~\Anaconda3\envs\ztfsummer\lib\site-packages\ztfquery\ztftable.py in show_gri_fields(self, sizeentry, grid, filterprop, **kwargs)
#     108         fieldsi = func(sizeentry, fid=3, grid=grid, **filterprop)
#     109         # Plot
# --> 110         return fields.show_gri_fields(fieldsg, fieldsr, fieldsi, grid=grid, **kwargs)
#     111
#     112     def show_evolution(self, value, timekey=None, ax=None, filterprop={},
#
# ~\Anaconda3\envs\ztfsummer\lib\site-packages\ztfquery\fields.py in show_gri_fields(fieldsg, fieldsr, fieldsi, fig, title, alignment, show_ztf_fields, colorbar, show_mw, mw_b, mw_prop, projection, moveup, vscale, hscale, **kwargs)
#     524     # None
#     525     if len(used_fields) == 0:
# --> 526         raise ValueError("No fields given")
#     527
#     528     # Only one
#
# ValueError: No fields given
